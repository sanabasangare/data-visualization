# %% [markdown]
# ### Bar Chart - Total Number of websites online

# %%
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# #### Increasing the size of the figure

# %%
plt.figure(figsize=(20,10))

# %% [markdown]
# #### create a bar chart using the number of websites on the world wide web

# %%
years = [2000, 2002, 2005, 2007, 2010, 2012, 2014, 2015]
num_websites = [17, 38, 64, 121, 206, 697, 968, 863]

# %% [markdown]
# #### since these bars are by default width 0.8, adding 0.1 centers each bar

# %%
xs = [i + 0.1 for i, _ in enumerate(years)]

# %% [markdown]
# #### plot bars with left x-coordinates [xs], heights [num_websites]

# %%
plt.bar(xs, num_websites, color='green')

plt.ylabel("# of Websites (millions)")

plt.title("Total number of websites online")

plt.xticks([i + 0.1 for i, _ in enumerate(years)], years, color='blue')
# Out:
# ([<matplotlib.axis.XTick at 0x113954d90>,
#   <matplotlib.axis.XTick at 0x11393d810>,
#   <matplotlib.axis.XTick at 0x114016450>,
#   <matplotlib.axis.XTick at 0x11404b090>,
#   <matplotlib.axis.XTick at 0x11404b790>,
#   <matplotlib.axis.XTick at 0x11404be90>,
#   <matplotlib.axis.XTick at 0x1140565d0>,
#   <matplotlib.axis.XTick at 0x114056cd0>],
#  <a list of 8 Text xticklabel objects>)

# %% [markdown]
# #### label x-axis with the years at bar centers

# %%
plt.show()
